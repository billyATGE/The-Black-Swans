# %%
# !pip install pytrends
import pandas as pd  
from scipy.stats import normaltest
from scipy import stats
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
pytrend = TrendReq()
# Out:
# Requirement already satisfied: pytrends in c:\users\stesk\.conda\envs\pythondata\lib\site-packages (4.7.3)
# Requirement already satisfied: lxml in c:\users\stesk\.conda\envs\pythondata\lib\site-packages (from pytrends) (4.5.2)
# Requirement already satisfied: requests in c:\users\stesk\.conda\envs\pythondata\lib\site-packages (from pytrends) (2.24.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\stesk\.conda\envs\pythondata\lib\site-packages (from pytrends) (1.0.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\stesk\.conda\envs\pythondata\lib\site-packages (from requests->pytrends) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\stesk\.conda\envs\pythondata\lib\site-packages (from requests->pytrends) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\stesk\.conda\envs\pythondata\lib\site-packages (from requests->pytrends) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\stesk\.conda\envs\pythondata\lib\site-packages (from requests->pytrends) (1.25.9)
# Requirement already satisfied: pytz>=2017.2 in c:\users\stesk\.conda\envs\pythondata\lib\site-packages (from pandas>=0.25->pytrends) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\stesk\.conda\envs\pythondata\lib\site-packages (from pandas>=0.25->pytrends) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\stesk\.conda\envs\pythondata\lib\site-packages (from pandas>=0.25->pytrends) (1.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\stesk\.conda\envs\pythondata\lib\site-packages (from python-dateutil>=2.6.1->pandas>=0.25->pytrends) (1.15.0)

# %%
pytrend.build_payload(kw_list = ["food near me","diet","gym","Health","Beach"],timeframe='2017-09-01 2021-03-17',geo='US')
df_A = pytrend.interest_over_time()

# %%
pytrend.build_payload(kw_list = ["diet pills","antidepressant"],timeframe='2017-09-01 2021-03-17',geo='US')
df_B = pytrend.interest_over_time()

# %%
df_C = pytrend.get_historical_interest(["food near me","Health","Beach"],year_start=2020, month_start=12, day_start=20, hour_start=0, year_end=2020, month_end=12, day_end=31, hour_end=0, cat=0, geo='US', sleep=240)

# %%
pytrend.build_payload(kw_list = ["christmas","diet"],timeframe='2015-09-01 2021-03-17',geo='US')
christmas_v_diet_df = pytrend.interest_over_time()

# %%
pytrend.build_payload(kw_list = ["restaurants open on christmas","restaurants open on thanksgiving","restaurants open on easter"],timeframe='2017-09-01 2021-03-17',geo='US')
holidays_restaurants_df = pytrend.interest_over_time()

# %%
pytrend.build_payload(kw_list = ["gym","diet"],timeframe='2015-09-01 2021-03-17',geo='US')
gym_v_diet_df = pytrend.interest_over_time()

# %%
pytrend.build_payload(kw_list = ["food near me","restauant near me"],timeframe='2017-09-01 2021-03-17',geo='US')
food_v_restauant_df = pytrend.interest_over_time()

# %%
pytrend.build_payload(kw_list = ["diet pills","diet"],timeframe='2015-09-01 2021-03-17',geo='US')
diet_pills_v_diet_df = pytrend.interest_over_time()

# %%
pytrend.build_payload(kw_list = ["holiday","diet"],timeframe='2015-09-01 2021-03-17',geo='US')
holiday_v_diet_df = pytrend.interest_over_time()

# %%
pytrend.build_payload(kw_list = ["Hydroxycut","Garcinia Cambogia Extract","Raspberry Ketones","Orlistat"],timeframe='2015-09-01 2021-03-17',geo='US')
diet_method_df = pytrend.interest_over_time()

# %%
pytrend.build_payload(kw_list = ["Bumble","tinder","OkCupid","hinge","coffee meets bagel"],timeframe='2015-09-01 2021-03-17',geo='US')
dating_method_df = pytrend.interest_over_time()

# %%
pytrend.build_payload(kw_list = ["food near me","diet","gym","Health","christmas"],timeframe='2015-09-01 2021-03-17',geo='US')
df_A_christmas = pytrend.interest_over_time()

# %%
#here
pytrend.build_payload(kw_list = ["gym","workout plan","running"],timeframe='2015-09-01 2021-03-17',geo='US')
gym_N_running_df = pytrend.interest_over_time()

# %%
pytrend.build_payload(kw_list = ["tanning bed","bikini waxing"],timeframe='2015-09-01 2021-03-17',geo='US')
tanning_N_bikini_df = pytrend.interest_over_time()

# %%
pytrend.build_payload(kw_list = ["liposuction","gastric sleeve", "Bariatric","personal loan"],timeframe='2015-09-01 2021-03-17',geo='US')
payday_load_N_liposuction_df = pytrend.interest_over_time()

# %%
pytrend.build_payload(kw_list = ["avant","lending club", "OneMain Financial","credit card loan","lending tree"],timeframe='2015-09-01 2021-03-17',geo='US')
personal_loan_method_df = pytrend.interest_over_time()

# %%
df_A.reset_index().plot(kind='line',x='date',title= 'Search Trends', style='-o', cmap='Dark2',figsize=(20,6), rot=30)

# %%
df_B.reset_index().plot(kind='line',x='date',title= 'Search Trends', style='-o', cmap='Dark2',figsize=(20,6), rot=30)

# %%
df_C.reset_index().plot(kind='line',x='date',title= 'Search Trends', style='-o', cmap='Dark2',figsize=(20,6), rot=30)

# %%
df_A.corr(method='spearman').drop('isPartial', axis=1).drop(['isPartial'])
# Out:
#               food near me      diet       gym    Health     Beach
# food near me      1.000000 -0.398699 -0.193977  0.322895  0.242419
# diet             -0.398699  1.000000  0.580306 -0.357693  0.485917
# gym              -0.193977  0.580306  1.000000 -0.340511  0.304834
# Health            0.322895 -0.357693 -0.340511  1.000000 -0.227977
# Beach             0.242419  0.485917  0.304834 -0.227977  1.000000

# %%
df_B.corr(method='spearman').drop('isPartial', axis=1).drop(['isPartial'])
# Out:
#                 diet pills  antidepressant
# diet pills        1.000000        0.223019
# antidepressant    0.223019        1.000000

# %%
df_C.corr(method='spearman').drop('isPartial', axis=1).drop(['isPartial'])
# Out:
#               food near me    Health     Beach
# food near me      1.000000 -0.337606 -0.251749
# Health           -0.337606  1.000000  0.625422
# Beach            -0.251749  0.625422  1.000000

# %%
christmas_v_diet_df.corr(method='spearman')
# Out:
#            christmas      diet
# christmas   1.000000 -0.466487
# diet       -0.466487  1.000000

# %%
thanksgiving_v_diet_df.corr(method='spearman')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-2f820a15d630> in <module>
# ----> 1 thanksgiving_v_diet_df.corr(method='spearman')
#
# NameError: name 'thanksgiving_v_diet_df' is not defined

# %%
Independence_Day_v_diet_df.corr(method='spearman')
# Out:
#                   Independence Day      diet
# Independence Day          1.000000  0.057521
# diet                      0.057521  1.000000

# %%
holiday_v_diet_df.corr(method='spearman')
# Out:
#           holiday      diet
# holiday  1.000000 -0.324968
# diet    -0.324968  1.000000

# %%
food_near_v_diet_df.corr(method='spearman')
# Out:
#               food near me      diet
# food near me      1.000000 -0.108157
# diet             -0.108157  1.000000

# %%
gym_v_diet_df.corr(method='spearman')
# Out:
#            gym      diet
# gym   1.000000  0.626313
# diet  0.626313  1.000000

# %%
diet_pills_v_diet_df.corr(method='spearman')
# Out:
#             diet pills      diet
# diet pills    1.000000  0.244743
# diet          0.244743  1.000000

# %%
diet_pills_v_gym_df.corr(method='spearman')
# Out:
#             diet pills       gym
# diet pills    1.000000  0.407323
# gym           0.407323  1.000000

# %%
new_year_v_diet_df.corr(method='spearman')
# Out:
#           New Year     diet
# New Year   1.00000 -0.07861
# diet      -0.07861  1.00000

# %%
df_A.corrwith(df_B['diet pills'], method='spearman').drop(['isPartial'])
# Out:
# C:\Users\stesk\.conda\envs\PythonData\lib\site-packages\scipy\stats\stats.py:4196: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# food near me   -0.201854
# diet            0.690524
# gym             0.385636
# Health         -0.270957
# Beach           0.632023
# dtype: float64

# %%
df_A.corrwith(df_B['antidepressant'], method='spearman').drop(['isPartial'])
# Out:
# food near me   -0.033003
# diet            0.300983
# gym             0.103055
# Health          0.016017
# Beach           0.039505
# dtype: float64

# %%
df_A.corrwith(suicide_v_guns_df['guns'], method='spearman').drop(['isPartial'])
# Out:
# food near me   -0.254588
# diet           -0.192669
# gym            -0.453609
# Health          0.678928
# Beach          -0.587181
# dtype: float64

# %%
diet_method_df.corrwith(df_B['diet pills'], method='spearman')
# Out:
# Hydroxycut                   0.927426
# Garcinia Cambogia Extract    0.857493
# Raspberry Ketones            0.842701
# Orlistat                    -0.074074
# dtype: float64

# %%
dating_method_df.corrwith(diet_method_df['Hydroxycut'], method="spearman")
# Out:
# Bumble               -0.134382
# tinder               -0.623307
# OkCupid               0.738392
# hinge                -0.694975
# coffee meets bagel    0.562532
# dtype: float64

# %%
food_ads_df  = dating_method_df.corrwith(df_A['food near me'], method="spearman")

# %%
diet_ads_df = dating_method_df.corrwith(df_A['diet'], method="spearman")

# %%
gym_ads_df = dating_method_df.corrwith(df_A['gym'], method="spearman")

# %%
health_ads_df = dating_method_df.corrwith(df_A['Health'], method="spearman")

# %%
beach_ads_df = dating_method_df.corrwith(df_A['Beach'], method="spearman")

# %%
frames = [food_ads_df,diet_ads_df,gym_ads_df,health_ads_df,beach_ads_df]
dating_ads_df = pd.concat(frames,axis=1, join="inner")

# %%
dating_ads_df = dating_ads_df.rename(columns={0:"Food",1:"Diet",2:"Gym",3:"Health",4:"Beach"})

# %%
dating_ads_df
# Out:
#                         Food      Diet       Gym    Health     Beach
# Bumble             -0.311940  0.490909  0.337100 -0.513783  0.720750
# tinder              0.009175  0.627273  0.764093 -0.339464  0.774806
# OkCupid            -0.691023  0.522544  0.133631 -0.272772  0.571429
# hinge               0.798199 -0.700000 -0.134840 -0.119271 -0.522544
# coffee meets bagel -0.770869  0.542720 -0.074536 -0.355005  0.517932

# %%
dating_ads_df.plot(kind="bar",figsize=(15,7),grid=True,title="Dating Sites Vs Search Requests")

# %%
df_A.corrwith(dating_method_df['hinge'], method="spearman").drop(['isPartial'])
# Out:
# food near me    0.792825
# diet           -0.536364
# gym            -0.134840
# Health          0.254545
# Beach          -0.445455
# dtype: float64

# %%
christmas_v_diet_df.corrwith(pizza_v_food_df['pizza'], method="spearman" )
# Out:
# christmas   -0.360101
# diet         0.189801
# dtype: float64

# %%
df_A_christmas.corr(method="spearman")
# Out:
#               food near me      diet       gym    Health  christmas
# food near me      1.000000 -0.182128 -0.117894  0.581961   0.036619
# diet             -0.182128  1.000000  0.569106 -0.153883  -0.470786
# gym              -0.117894  0.569106  1.000000 -0.175833  -0.264154
# Health            0.581961 -0.153883 -0.175833  1.000000  -0.113135
# christmas         0.036619 -0.470786 -0.264154 -0.113135   1.000000

# %%
df_C_christmas_total_df = pd.concat([df_C_christmas_2020_df,df_C_christmas_2019_df,df_C_christmas_2018_df,df_C_christmas_2017_df,df_C_christmas_2016_df])

# %%
df_C_thanksgiving_total_df = pd.concat([df_C_thanksgiving_2020_df,df_C_thanksgiving_2019_df,df_C_thanksgiving_2018_df,df_C_thanksgiving_2017_df,df_C_thanksgiving_2016_df])

# %%
df_A.corrwith(df_C_christmas_total_df['christmas'], method="spearman").drop(['isPartial'])
# Out:
# C:\Users\stesk\.conda\envs\PythonData\lib\site-packages\scipy\stats\stats.py:4196: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# food near me   -0.231908
# diet            0.405840
# gym             0.441367
# Health          0.173931
# Beach           0.405840
# dtype: float64

# %%
df_C_christmas_total_df.corr(method="spearman").drop(['isPartial']).drop('isPartial', axis=1)
# Out:
#               food near me  christmas      diet       gym    health
# food near me      1.000000   0.612139  0.757280  0.684117  0.699975
# christmas         0.612139   1.000000  0.464269  0.451243  0.299593
# diet              0.757280   0.464269  1.000000  0.919810  0.832813
# gym               0.684117   0.451243  0.919810  1.000000  0.785813
# health            0.699975   0.299593  0.832813  0.785813  1.000000

# %%
df_A_christmas.corr(method="spearman")
# Out:
#               food near me      diet       gym    Health  christmas
# food near me      1.000000 -0.182128 -0.117894  0.581961   0.036619
# diet             -0.182128  1.000000  0.569106 -0.153883  -0.470786
# gym              -0.117894  0.569106  1.000000 -0.175833  -0.264154
# Health            0.581961 -0.153883 -0.175833  1.000000  -0.113135
# christmas         0.036619 -0.470786 -0.264154 -0.113135   1.000000

# %%
df_C_holidays_total_df = pd.concat([df_C_christmas_total_df,df_C_thanksgiving_total_df])

# %%
df_A.corrwith(df_C_holidays_total_df['christmas'], method="spearman").drop(['isPartial'])
# Out:
# C:\Users\stesk\.conda\envs\PythonData\lib\site-packages\scipy\stats\stats.py:4196: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# food near me   -0.231908
# diet            0.405840
# gym             0.441367
# Health          0.173931
# Beach           0.405840
# dtype: float64

# %%
df_A.corrwith(df_C_holidays_total_df['thanksgiving'], method="spearman").drop(['isPartial'])
# Out:
# food near me    0.632456
# diet           -0.400000
# gym             0.316228
# Health         -0.800000
# Beach           0.316228
# dtype: float64

# %%
df_A.corrwith(df_A_christmas['christmas'], method="spearman").drop(['isPartial'])
# Out:
# food near me    0.018019
# diet           -0.890909
# gym            -0.494413
# Health         -0.090909
# Beach          -0.718182
# dtype: float64

# %%
df_C_holidays_total_df.corr(method="spearman").drop(['isPartial'], axis=1).drop(['isPartial'])
# Out:
#               food near me  christmas      diet       gym    health  \
# food near me      1.000000   0.612139  0.779900  0.744022  0.722764
# christmas         0.612139   1.000000  0.464269  0.451243  0.299593
# diet              0.779900   0.464269  1.000000  0.936113  0.854779
# gym               0.744022   0.451243  0.936113  1.000000  0.818409
# health            0.722764   0.299593  0.854779  0.818409  1.000000
# thanksgiving      0.463416        NaN  0.365530  0.428334  0.338020
#
#               thanksgiving
# food near me      0.463416
# christmas              NaN
# diet              0.365530
# gym               0.428334
# health            0.338020
# thanksgiving      1.000000

# %%
gym_N_running_df.corr(method="spearman")
# Out:
#                    gym  workout plan  running
# gym           1.000000      0.440517 -0.30231
# workout plan  0.440517      1.000000 -0.15785
# running      -0.302310     -0.157850  1.00000

# %%
df_A.corrwith(gym_N_running_df['workout plan'],method="spearman").drop(['isPartial'])
# Out:
# C:\Users\stesk\.conda\envs\PythonData\lib\site-packages\scipy\stats\stats.py:4196: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
# food near me   -0.408248
# diet            0.617914
# gym             0.763763
# Health          0.102986
# Beach           0.617914
# dtype: float64

# %%
df_A.corrwith(tanning_N_bikini_df['bikini waxing'],method="spearman").drop(['isPartial'])
# Out:
# food near me   -0.299392
# diet            0.698611
# gym             0.420084
# Health         -0.623085
# Beach           0.868543
# dtype: float64

# %%
df_A.corrwith(tanning_N_bikini_df['tanning bed'],method="spearman").drop(['isPartial'])
# Out:
# food near me   -0.107143
# diet            0.900937
# gym             0.801784
# Health          0.234244
# Beach           0.738769
# dtype: float64

# %%
payday_load_N_liposuction_l = df_A.corrwith(payday_load_N_liposuction_df['liposuction'],method="spearman").drop(['isPartial'])
payday_load_N_liposuction_l_df = pd.DataFrame(data=payday_load_N_liposuction_l, columns=['liposuction'])
payday_load_N_liposuction_l_df
# Out:
#               liposuction
# food near me    -0.535714
# diet             0.414431
# gym             -0.133631
# Health          -0.522544
# Beach            0.360375

# %%
payday_load_N_liposuction_g = df_A.corrwith(payday_load_N_liposuction_df['gastric sleeve'],method="spearman").drop(['isPartial'])
payday_load_N_liposuction_g_df = pd.DataFrame(data=payday_load_N_liposuction_g, columns=['gastric sleeve'])
payday_load_N_liposuction_g_df
# Out:
# C:\Users\stesk\.conda\envs\PythonData\lib\site-packages\scipy\stats\stats.py:4196: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
#               gastric sleeve
# food near me       -0.370625
# diet                0.411377
# gym                 0.323575
# Health             -0.411377
# Beach               0.467473

# %%
payday_load_N_liposuction_b = df_A.corrwith(payday_load_N_liposuction_df['Bariatric'],method="spearman").drop(['isPartial'])
payday_load_N_liposuction_b_df = pd.DataFrame(data=payday_load_N_liposuction_b, columns=['Bariatric'])
payday_load_N_liposuction_b_df
# Out:
# C:\Users\stesk\.conda\envs\PythonData\lib\site-packages\scipy\stats\stats.py:4196: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
#               Bariatric
# food near me  -0.250000
# diet           0.594619
# gym            0.356348
# Health        -0.684712
# Beach          0.774806

# %%
payday_load_N_liposuction_p = df_A.corrwith(payday_load_N_liposuction_df['personal loan'],method="spearman").drop(['isPartial'])
payday_load_N_liposuction_p_df = pd.DataFrame(data=payday_load_N_liposuction_p, columns=['personal loan'])
payday_load_N_liposuction_p_df
# Out:
# C:\Users\stesk\.conda\envs\PythonData\lib\site-packages\scipy\stats\stats.py:4196: SpearmanRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(SpearmanRConstantInputWarning())
#               personal loan
# food near me       0.214286
# diet               0.396412
# gym                0.668153
# Health            -0.180187
# Beach              0.630656

# %%
payday_load_N_liposuction_frames = [payday_load_N_liposuction_p_df,payday_load_N_liposuction_b_df , payday_load_N_liposuction_g_df,payday_load_N_liposuction_l_df]
payday_load_N_liposuction_all_df = pd.concat(payday_load_N_liposuction_frames,axis=1, join="inner")
#sn.heatmap(payday_load_N_liposuction_all_df, cmap="blue", annot=True)
sn.heatmap(payday_load_N_liposuction_all_df,cmap="YlGnBu",annot=True)

# %%
payday_load_N_liposuction_all_df.plot(kind='bar',figsize=(15,7),rot=0, grid=True, title='Plastic surgery methods v Personal Loans')

# %%
payday_load_N_liposuction_all_df.plot(kind='line',figsize=(15,7),rot=0, grid=True, title='Plastic surgery methods v Personal Loans')

# %%
personal_loan_method_b  = personal_loan_method_df.corrwith(df_A['Beach'],method="spearman")
personal_loan_method_b_df = pd.DataFrame(data=personal_loan_method_b, columns=['Beach'])
personal_loan_method_b_df
# Out:
#                       Beach
# avant              0.468487
# lending club       0.663636
# OneMain Financial  0.408712
# credit card loan   0.745814
# lending tree       0.745455

# %%
personal_loan_method_d = personal_loan_method_df.corrwith(df_A['diet'],method="spearman")
personal_loan_method_d_df = pd.DataFrame(data=personal_loan_method_d, columns=['diet'])
personal_loan_method_d_df
# Out:
#                        diet
# avant              0.234244
# lending club       0.872727
# OneMain Financial  0.447637
# credit card loan   0.472034
# lending tree       0.845455

# %%
personal_loan_method_h = personal_loan_method_df.corrwith(df_A['Health'],method="spearman")
personal_loan_method_h_df = pd.DataFrame(data=personal_loan_method_h, columns=['Health'])
personal_loan_method_h_df
# Out:
#                      Health
# avant             -0.054056
# lending club      -0.072727
# OneMain Financial -0.291937
# credit card loan  -0.821340
# lending tree      -0.281818

# %%
personal_loan_method_g = personal_loan_method_df.corrwith(df_A['gym'],method="spearman")
personal_loan_method_g_df = pd.DataFrame(data=personal_loan_method_g, columns=['gym'])
personal_loan_method_g_df
# Out:
#                         gym
# avant              0.801784
# lending club       0.404520
# OneMain Financial  0.240563
# credit card loan   0.163366
# lending tree       0.337100

# %%
frames = [personal_loan_method_g_df, personal_loan_method_h_df, personal_loan_method_d_df,personal_loan_method_b_df]
personal_loan_method_all_df = pd.concat(frames,axis=1, join="inner")
sn.heatmap(personal_loan_method_all_df, cmap="Blues", annot=True)

# %%
personal_loan_method_all_df.plot(kind='bar',figsize=(15,7),rot=0, grid=True, title='Loan Methods v Personalities')
plt.show()

# %%
personal_loan_method_all_df.plot(kind='line',figsize=(15,7),rot=0, grid=True, title='Loan Methods v Personalities')
plt.show()

# %%
personal_loan_method_all_df.plot.box(figsize=(15,7),rot=0, grid=True, title='Loan Methods v Personalities')
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(211)
ax2 = fig.add_subplot(212)
fig, ([ax1, ax2]) = plt.subplots(2,1)
fig.suptitle('Loan Methods v Personalities', fontsize=14, fontweight='bold')
ax1.boxplot(personal_loan_method_all_df)
ax2.boxplot(payday_load_N_liposuction_all_df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1df35320b38>,
#   <matplotlib.lines.Line2D at 0x1df35320eb8>,
#   <matplotlib.lines.Line2D at 0x1df35338390>,
#   <matplotlib.lines.Line2D at 0x1df353386d8>,
#   <matplotlib.lines.Line2D at 0x1df35345ac8>,
#   <matplotlib.lines.Line2D at 0x1df35345e10>,
#   <matplotlib.lines.Line2D at 0x1df3535c240>,
#   <matplotlib.lines.Line2D at 0x1df3535c588>,
#   <matplotlib.lines.Line2D at 0x1df35369978>,
#   <matplotlib.lines.Line2D at 0x1df35369cc0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1df3532c278>,
#   <matplotlib.lines.Line2D at 0x1df3532c5f8>,
#   <matplotlib.lines.Line2D at 0x1df35338a20>,
#   <matplotlib.lines.Line2D at 0x1df35338d68>,
#   <matplotlib.lines.Line2D at 0x1df35351198>,
#   <matplotlib.lines.Line2D at 0x1df353514e0>,
#   <matplotlib.lines.Line2D at 0x1df3535c8d0>,
#   <matplotlib.lines.Line2D at 0x1df3535cc18>,
#   <matplotlib.lines.Line2D at 0x1df35376048>,
#   <matplotlib.lines.Line2D at 0x1df35376390>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1df352ca278>,
#   <matplotlib.lines.Line2D at 0x1df3532cfd0>,
#   <matplotlib.lines.Line2D at 0x1df35345748>,
#   <matplotlib.lines.Line2D at 0x1df35351e80>,
#   <matplotlib.lines.Line2D at 0x1df353695f8>],
#  'medians': [<matplotlib.lines.Line2D at 0x1df3532c978>,
#   <matplotlib.lines.Line2D at 0x1df353450f0>,
#   <matplotlib.lines.Line2D at 0x1df35351828>,
#   <matplotlib.lines.Line2D at 0x1df3535cf60>,
#   <matplotlib.lines.Line2D at 0x1df353766d8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1df3532ccc0>,
#   <matplotlib.lines.Line2D at 0x1df35345438>,
#   <matplotlib.lines.Line2D at 0x1df35351b70>,
#   <matplotlib.lines.Line2D at 0x1df353692e8>,
#   <matplotlib.lines.Line2D at 0x1df35376a20>],
#  'means': []}

# %%
coef, pvalue = stats.spearmanr(gym_N_running_df['gym'],gym_N_running_df['running'])
print(coef)
# Out:
# -0.30231017748435085

# %%
personal_loan_method_all_df
# Out:
#                         gym    Health      diet     Beach
# avant              0.801784 -0.054056  0.234244  0.468487
# lending club       0.404520 -0.072727  0.872727  0.663636
# OneMain Financial  0.240563 -0.291937  0.447637  0.408712
# credit card loan   0.163366 -0.821340  0.472034  0.745814
# lending tree       0.337100 -0.281818  0.845455  0.745455

# %%
coef, pvalue = stats.spearmanr(gym_N_running_df['gym'],gym_N_running_df['running'])
print(coef)
# Out:
# -0.27233774329943566

# %%
plt.bar(gym_N_running_df['gym'],gym_N_running_df['running'])
# Out:
# <BarContainer object of 67 artists>

# %%
gym_N_running_df.plot(kind='line')
